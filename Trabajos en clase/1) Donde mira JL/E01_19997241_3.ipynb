# %% [markdown]
# <font color='orange'>WARNING-1: No se aceptan soluciones que usen metodologías distintas a la vista en clases.

# %% [markdown]
# # 0) Cambiar el nombre del archivo
#
# <font color='red'>WARNING-2: CAMBIA EL NOMBRE DEL ARCHIVO ipynb INCLUYENDO TU RUT</font>
#
# Ejemplo, si tu RUT es 12.345.678-9, el nombre de este archivo debe cambiarse de "E01_Tu_Rut.ipynb" a "E01_12345678-9.ipynb"

# %% [markdown]
# # 1) Librerías
#
# (1 Punto)
#
# *Todas las librerías de este código deben ir en esta celda. Sólo está permitido usar las librerías del ejemplo visto en clase.*

# %%
 # PREGUNTA 1: ESCRIBA CODIGO AQUI
 import numpy as np
 import matplotlib.pyplot as plt
 import cv2

# %% [markdown]
# # 2) Rectas y líneas
#
#
#
#
# *   Encuentre la ecuación de la recta que pasa por los puntos (3,5) y (7,8)
# *   Encuentre la intersección de la recta $y=2x+3$ con la recta $y=-x$
#
# <font color='orange'>VER WARNING-1 MAS ARRIBA</font>

# %%
 # PREGUNTA 2: ESCRIBA CODIGO AQUI
p1 = [3,5,1]
p2 = [7,8,1]

l = np.cross(p1,p2)

a = l[0]
b = l[1]
c = l[2]

x = [p1[0], p2[0]]
y = [p1[1], p2[1]]

print(l)
print("Ecuación de la recta: ", str(a) +"x + "+str(b) +"y + "+ str(c) + "= 0")

plt.plot(x,y)
# Out:
# [ -3   4 -11]
# Ecuación de la recta:  -3x + 4y + -11= 0

# %%
#recta 1
l1 = [2, -1, 3]

#recta 2
l2 = [1, 1, 0]

#Intersección
inter = np.cross(l1,l2)

x_int = inter[0]/inter[2]
y_int = inter[1]/inter[2]

print("intersección (x,y) = ", (x_int, y_int))
# Out:
# intersección (x,y) =  (-1.0, 1.0)

# %% [markdown]
# # 3) Cargue la Imagen de John Lennon y Despliéguela
#
# (1 Punto)
#
# *Lea erchivo de la imagen se encuentra en este link:*
#
# `https://www.dropbox.com/s/g4hee0epvla4n5j/JohnLennon.jpg`

# %%
 # PREGUNTA 3: ESCRIBA CODIGO AQUI

 # !wget https://www.dropbox.com/s/g4hee0epvla4n5j/JohnLennon.jpg

 image = cv2.imread("JohnLennon.jpg")
# Out:
# --2022-08-18 02:13:11--  https://www.dropbox.com/s/g4hee0epvla4n5j/JohnLennon.jpg
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/g4hee0epvla4n5j/JohnLennon.jpg [following]
# --2022-08-18 02:13:12--  https://www.dropbox.com/s/raw/g4hee0epvla4n5j/JohnLennon.jpg
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca73549e6f90f8bc0a17572f82d.dl.dropboxusercontent.com/cd/0/inline/BrNb132ulVDRYK7GHWiygyTSpYljUQ3-FlSF_1UGDMuFXWVVGarqH629SMv8wwoHFhXbkw1_sND3XF-1HvOGjo0t07VPzirQO_ojMh_D2iqj7GTCKD_sMSdlSZgwqg5Yl2xglxfJkPLIqkfE-4n4-e8P5EZ1AbYwbrEk2S45ds5yWg/file# [following]
# --2022-08-18 02:13:12--  https://uca73549e6f90f8bc0a17572f82d.dl.dropboxusercontent.com/cd/0/inline/BrNb132ulVDRYK7GHWiygyTSpYljUQ3-FlSF_1UGDMuFXWVVGarqH629SMv8wwoHFhXbkw1_sND3XF-1HvOGjo0t07VPzirQO_ojMh_D2iqj7GTCKD_sMSdlSZgwqg5Yl2xglxfJkPLIqkfE-4n4-e8P5EZ1AbYwbrEk2S45ds5yWg/file
# Resolving uca73549e6f90f8bc0a17572f82d.dl.dropboxusercontent.com (uca73549e6f90f8bc0a17572f82d.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uca73549e6f90f8bc0a17572f82d.dl.dropboxusercontent.com (uca73549e6f90f8bc0a17572f82d.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63506 (62K) [image/jpeg]
# Saving to: ‘JohnLennon.jpg’
#
# JohnLennon.jpg      100%[===================>]  62.02K  --.-KB/s    in 0.02s
#
# 2022-08-18 02:13:12 (3.40 MB/s) - ‘JohnLennon.jpg’ saved [63506/63506]

# %% [markdown]
# # 4) Cargue las coordenadas (x,y) de los 68 Landmarks
#
# (1 Punto)
#
# *Los archivos de la coordenadas son:*
#
# `https://www.dropbox.com/s/6xfjsz0ymbctbhr/JL_landmarks_x.npy`
#
# `https://www.dropbox.com/s/18chd3jdw95vmt7/JL_landmarks_y.npy`
#
# *Cargue en `x` el primero archivo, y en `y` el segundo archivo*
#
# Help: [Cómo cargar archivos npy ?](https://www.google.com/search?q=como+cargar+archivos+npy)

# %%
 # PREGUNTA 4: ESCRIBA CODIGO AQUI

# !wget https://www.dropbox.com/s/6xfjsz0ymbctbhr/JL_landmarks_x.npy

# !wget https://www.dropbox.com/s/18chd3jdw95vmt7/JL_landmarks_y.npy

xland = np.load("JL_landmarks_x.npy")
yland = np.load("JL_landmarks_y.npy")
# Out:
# --2022-08-18 02:14:10--  https://www.dropbox.com/s/6xfjsz0ymbctbhr/JL_landmarks_x.npy
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/6xfjsz0ymbctbhr/JL_landmarks_x.npy [following]
# --2022-08-18 02:14:10--  https://www.dropbox.com/s/raw/6xfjsz0ymbctbhr/JL_landmarks_x.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucb9983177df07b8f3665d642677.dl.dropboxusercontent.com/cd/0/inline/BrPDvXxuq_9EzyrgvY2IuA4cYX3Ler5ddxsdO0nkVi-nA1RFIKjeJTNhN_gW0DoCRvA8EjUrI_5KGKi1zutlP9c7cMwp5vWc3jGTUCtKpS-Wj5_PM5qsSqZRdSEvqaYm9CQGITZ21bC6LLDkJ_0Z4j0wxD8WC6006RMcjycXaQoBTg/file# [following]
# --2022-08-18 02:14:10--  https://ucb9983177df07b8f3665d642677.dl.dropboxusercontent.com/cd/0/inline/BrPDvXxuq_9EzyrgvY2IuA4cYX3Ler5ddxsdO0nkVi-nA1RFIKjeJTNhN_gW0DoCRvA8EjUrI_5KGKi1zutlP9c7cMwp5vWc3jGTUCtKpS-Wj5_PM5qsSqZRdSEvqaYm9CQGITZ21bC6LLDkJ_0Z4j0wxD8WC6006RMcjycXaQoBTg/file
# Resolving ucb9983177df07b8f3665d642677.dl.dropboxusercontent.com (ucb9983177df07b8f3665d642677.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:601b:15::a27d:80f
# Connecting to ucb9983177df07b8f3665d642677.dl.dropboxusercontent.com (ucb9983177df07b8f3665d642677.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 624 [text/plain]
# Saving to: ‘JL_landmarks_x.npy’
#
# JL_landmarks_x.npy  100%[===================>]     624  --.-KB/s    in 0s
#
# 2022-08-18 02:14:11 (124 MB/s) - ‘JL_landmarks_x.npy’ saved [624/624]
#
# --2022-08-18 02:14:11--  https://www.dropbox.com/s/18chd3jdw95vmt7/JL_landmarks_y.npy
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/18chd3jdw95vmt7/JL_landmarks_y.npy [following]
# --2022-08-18 02:14:11--  https://www.dropbox.com/s/raw/18chd3jdw95vmt7/JL_landmarks_y.npy
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucf56be8d47ebf98b17c2bb5d8db.dl.dropboxusercontent.com/cd/0/inline/BrNo_SgRMC1P5_vgPvHEK_ThR9CckBHJT-f9iE3na2rf-vu6lh8UiszrXpaeVdWSyXJLG4dZzhYqAKmO2vIar8UM2nBlY7Q8z1A7lKdFhvVXmm7WpFWUD21nTR_ngMAHXqlUFKf-r98w3j-8esebytECnh3dP9oD-1ZkPiu9waTdfA/file# [following]
# --2022-08-18 02:14:11--  https://ucf56be8d47ebf98b17c2bb5d8db.dl.dropboxusercontent.com/cd/0/inline/BrNo_SgRMC1P5_vgPvHEK_ThR9CckBHJT-f9iE3na2rf-vu6lh8UiszrXpaeVdWSyXJLG4dZzhYqAKmO2vIar8UM2nBlY7Q8z1A7lKdFhvVXmm7WpFWUD21nTR_ngMAHXqlUFKf-r98w3j-8esebytECnh3dP9oD-1ZkPiu9waTdfA/file
# Resolving ucf56be8d47ebf98b17c2bb5d8db.dl.dropboxusercontent.com (ucf56be8d47ebf98b17c2bb5d8db.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to ucf56be8d47ebf98b17c2bb5d8db.dl.dropboxusercontent.com (ucf56be8d47ebf98b17c2bb5d8db.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 624 [text/plain]
# Saving to: ‘JL_landmarks_y.npy.2’
#
# JL_landmarks_y.npy. 100%[===================>]     624  --.-KB/s    in 0s
#
# 2022-08-18 02:14:11 (80.9 MB/s) - ‘JL_landmarks_y.npy.2’ saved [624/624]

# %% [markdown]
# # 5) Despliegue los 68 landmarks en la cara de John Lennon
# (2 Puntos)
#
# *Debe mostrar los 68 puntos sobre la imagen de John Lennon*

# %%
 # PREGUNTA 5: ESCRIBA CODIGO AQUI

 plt.figure(figsize=(10,10))

 plt.imshow(image)

 plt.scatter(xland,yland)

# %%
xland.shape
# Out:
# (1, 68)

# %% [markdown]
# # Usando el esquema de la siguiente figura encuentre hacia dónde mira John Lennon en la imagen cargada

# %% [markdown]
# ![Screen Shot 2021-08-22 at 7.40.19 am.png](data:image/png;base64,...)

# %% [markdown]
# # 6) Encuentre el cuadrilatero definido por los ojos y comisura de los labios
#
# (2 Puntos)
#
# *Siguiendo el esquema de la figura muestre el cuadrilatero de los cuatro puntos rojos, debe mostrar los cuatro puntos y la línea del cuadrilátero, sobre la imagen de John Lennon*
#
# [Cómo están definidos los 68 landmarks?](https://github.com/domingomery/vision/blob/master/clases/Cap02_Geometria/practice/facial_landmarks_68markup.jpg)

# %%
from matplotlib.transforms import blended_transform_factory
 # PREGUNTA 6: ESCRIBA CODIGO AQUI

plt.figure(figsize=(10,10))

ojo_i = [xland[0][36], yland[0][36]]
ojo_d = [xland[0][45], yland[0][45]]

boca_i = [xland[0][48], yland[0][48]] 
boca_d = [xland[0][54], yland[0][54]]

x = [ojo_i[0], boca_i[0], boca_d[0], ojo_d[0], ojo_i[0]]

y = [ojo_i[1], boca_i[1], boca_d[1], ojo_d[1], ojo_i[1]]

plt.imshow(image)

plt.plot(x,y)

plt.scatter(x,y)

# %% [markdown]
# # 7) Defina las coordenadas homogéneas de los cuatro puntos del cuadrilatero
#
# (1 Punto)
#
# Defina los siguientes 4 puntos en ccordenadas homogéneas e imprimalos con `print`.
#
# * Punto m1 : extremo externo del ojo izquierdo
#
# * Punto m2 : extremo externo de ojo derecho
#
# * Punto m3 : comisura izquierda del labio
#
# * Punto m4 : comisura derecha del labio

# %%
 # PREGUNTA 7: ESCRIBA CODIGO AQUI

 m1 = [ojo_i[0], ojo_i[1],1]
 m2 = [ojo_d[0], ojo_d[1],1]
 m3 = [boca_i[0], boca_i[1], 1]
 m4 = [boca_d[0], boca_d[1], 1]

 print(m1)
 print(m2)
 print(m3)
 print(m4)
# Out:
# [315.5, 293.0, 1]
# [402.5, 299.0, 1]
# [330.5, 374.0, 1]
# [389.0, 374.0, 1]

# %% [markdown]
# # 8) Encuentre mc, el centro del cuadrilátero y despliéguelo
#
# (2 Puntos)
#
# *Usando la metodología vista en clases -con coordenadas homogénas-, encuentre el centro del cuadrilatero como la intersección de la recta que pasa por (m1 y m4) con la recta que pasa por (m2 y m3).*
#
# *Debe mostrar los cuatro puntos del cuadrilátero, la línea del cuadrilátero, y el centro del cuadrilátero sobre la imagen de John Lennon.*

# %%
 # PREGUNTA 8: ESCRIBA CODIGO AQUI
plt.figure(figsize=(10,10))

#recta m1-m4
l14 = np.cross(m1,m4)

#recta m2-m3
l23 = np.cross(m2,m3)

#intersección rectas (centro)

centro = np.cross(l14, l23)

x_centro = centro[0]/centro[2]
y_centro = centro[1]/centro[2]

mc = [x_centro, y_centro, 1]

plt.imshow(image)

plt.plot(x,y)

plt.scatter(x,y)

plt.scatter(mc[0], mc[1])

# %% [markdown]
# # 9) Hacia dónde mira John Lennon? (Parte 1)
#
# (2 Punto)
#
# *Encuentre la ecuación de la recta que pasa por mc y la punta de la nariz y grafique esa línea desde mc hasta mq, donde mq es el punto de la línea en x=500.*
#
# *Debe mostrar los cuatro puntos del cuadrilátero, la línea del cuadrilátero, el centro del cuadrilátero, y la línea encontrada, sobre la imagen de John Lennon.*

# %%
 # PREGUNTA 9: ESCRIBA CODIGO AQUI

plt.figure(figsize=(10,10))

#punta de la nariz landmark 34 (en coordenadas homogeneas)

p_nariz = [xland[0][30], yland[0][33], 1]

#recta mc - p_nariz

m_nariz = np.cross(mc, p_nariz)

a   = m_nariz[0]
b   = m_nariz[1]
c   = m_nariz[2]

#Evaluación
x_mq = 500

y_mq = -(c+a*x_mq)/b

mq = [x_mq, y_mq,1]


plt.imshow(image)

plt.plot(x,y)

plt.scatter(x,y)

plt.scatter(mc[0], mc[1])

plt.plot([mc[0], mq[0]], [mc[1], mq[1]])

# %% [markdown]
# # 10) Hacia dónde mira John Lennon? (Parte 2)
#
# (2 Punto)
#
# *Desplace la línea encontrada en el paso anterior de tal forma que comience (no desde mc) sino desde mt, definido como el punto medio entre m1 y m2.*
#
# *Debe mostrar la nueva línea encontrada sobre la imagen de John Lennon.*

# %%
 # PREGUNTA 10: ESCRIBA CODIGO AQUI
plt.figure(figsize=(10,10))

#Punto medio

mt = [(m1[0] + m2[0])/2, (m1[1] + m2[1])/2, 1]

dx = mt[0] - mc[0] #cuanto hay que traladar en x para llegar desde el centro hasta el pto medio 

dy = mt[1]- mc[1] #cuanto hay que traladar en y para llegar desde el centro hasta el pto medio 


plt.imshow(image)

#trasladamos la recta

plt.plot([mt[0], mq[0]+dx], [mt[1], mq[1]+dy]) #Solo aplicamos la traslación al punto mq

# %% [markdown]
# # <font color='red'>SUBIR EJERCICIO DE FORMA INDIVIDUAL A CANVAS</font>
